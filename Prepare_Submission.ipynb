# %%
print("Welcome")
# Out:
# Welcome

# %% [markdown]
# graph TB
#     User[👤 User<br/>Voice/Text Input]
#
#     subgraph WebApp["🌐 FastAPI Web Application"]
#         Routes[API Routes]
#         Chat[Chat Interface]
#         Simulator[Trial Simulator]
#     end
#
#     subgraph Agentic["🤖 AGENTIC FRAMEWORK - Core Innovation"]
#         style Router fill:#FF6B6B,stroke:#C92A2A,stroke-width:4px,color:#fff
#
#         Router[🎯 Agent Router<br/><b>Intelligent Orchestration</b>]
#
#         subgraph Agents["Specialized AI Agents"]
#             Research[🔬 Research<br/>Data Analysis]
#             Predict[📈 Prediction<br/>Success Rate]
#             Optimize[⚡ Optimization<br/>Improvements]
#             Report[📋 Report<br/>Analysis]
#         end
#     end
#
#     Gemini[🧠 Google Gemini 2.5 Flash<br/><b>AI Engine</b>]
#
#     Data[(📊 Data Storage<br/>CSV Files)]
#
#     User --> WebApp
#     WebApp --> Router
#     Router --> Research
#     Router --> Predict
#     Router --> Optimize
#     Router --> Report
#     Research --> Gemini
#     Predict --> Gemini
#     Optimize --> Gemini
#     Report --> Gemini
#     Gemini --> Router
#     Router --> WebApp
#     WebApp --> User
#     WebApp <--> Data
#
#     classDef agentStyle fill:#51CF66,stroke:#2F9E44,stroke-width:3px
#     class Research,Predict,Optimize,Report agentStyle
#
#     style User fill:#E3F2FD,stroke:#1976D2,stroke-width:2px
#     style WebApp fill:#F3E5F5,stroke:#7B1FA2,stroke-width:2px
#     style Gemini fill:#FFF3E0,stroke:#F57C00,stroke-width:3px
#     style Data fill:#E8F5E9,stroke:#388E3C,stroke-width:2px
